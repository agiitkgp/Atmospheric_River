# %%
import os
import pandas as pd
import numpy as np
import xarray as xr
from datetime import datetime as dt
from scipy import integrate
import matplotlib.pyplot as plt
year = XXXX  # Change this as needed
month = "YY"  # Change this as needed (ensure two-digit format)
# Load data from NetCDF files
# Construct file paths dynamically
qdata = xr.open_dataset(f"/g/data/rt52/era5/pressure-levels/reanalysis/q/{year}/q_era5_oper_pl_{year}{month}01-{year}{month}28.nc")
q2mdata = xr.open_dataset(f"/g/data/k10/ak6086/q2m/{year}/q2m_{year}{month}.nc")
vdata = xr.open_dataset(f"/g/data/rt52/era5/pressure-levels/reanalysis/v/{year}/v_era5_oper_pl_{year}{month}01-{year}{month}28.nc")
v10mdata = xr.open_dataset(f"/g/data/rt52/era5/single-levels/reanalysis/10v/{year}/10v_era5_oper_sfc_{year}{month}01-{year}{month}28.nc")
spdata = xr.open_dataset(f"/g/data/rt52/era5/single-levels/reanalysis/sp/{year}/sp_era5_oper_sfc_{year}{month}01-{year}{month}28.nc")
time_steps = qdata.time
g=9.81
vIVT_all_timesteps = []
for tt in range(len(time_steps)):
    print(f"Processing time step {tt + 1}/{len(time_steps)}")

    # Extract surface pressure data
    p_s_xr_2d = spdata['sp'][tt, :, :]  # Surface pressure [Pa]
    p_s_2d = p_s_xr_2d.compute().values
    p_s_hPa_2d = p_s_2d / 1e2  # Convert pressure to hPa

    # Extract specific humidity at 2 meters and meridional velocity at 10 meters
    q2m_xr_2d = q2mdata['q2m'][tt, :, :]
    q2m_2d = q2m_xr_2d.compute().values
    v10_xr_2d = v10mdata['v10'][tt, :, :]
    v10_2d = v10_xr_2d.compute().values

    # Extract 3D specific humidity and meridional velocity
    xr_q_3d = qdata['q'][tt, :, :, :]  # Specific humidity [kg/kg]
    q_3d = xr_q_3d.compute().values
    xr_v_3d = vdata['v'][tt, :, :, :]  # Meridional velocity [m/s]
    v_3d = xr_v_3d.compute().values

    # Create copies for high-pressure calculations
    q_hi_3d = np.copy(q_3d)
    q2m_hi_2d = np.copy(q2m_2d)
    v_hi_3d = np.copy(v_3d)
    v10m_hi_2d = np.copy(v10_2d)

    # Set values to zero where surface pressure is less than 1000 hPa
    mask_low_pressure = p_s_hPa_2d < 1000
    q_hi_3d[:, mask_low_pressure] = 0.
    q2m_hi_2d[mask_low_pressure] = 0.
    v_hi_3d[:, mask_low_pressure] = 0.
    v10m_hi_2d[mask_low_pressure] = 0.

    # Reshape 2D fields to 3D for stacking
    q2m_hi_3d = q2m_hi_2d.reshape((1, q2m_hi_2d.shape[0], q2m_hi_2d.shape[1]))
    v10m_hi_3d = v10m_hi_2d.reshape((1, v10m_hi_2d.shape[0], v10m_hi_2d.shape[1]))

    # Stack high-pressure data
    q_hi_3d_stacked = np.append(q_hi_3d, q2m_hi_3d, axis=0)
    v_hi_3d_stacked = np.append(v_hi_3d, v10m_hi_3d, axis=0)

    # Define pressure levels
    p = qdata.level.values  # Pressure levels [hPa]
    p_levels_3d = np.zeros((len(p), q_3d.shape[1], q_3d.shape[2]))
    for i in range(len(p)):
        p_levels_3d[i, :, :] = p[i]

    # Add surface pressure as a new level
    p_s_hPa_3d = p_s_hPa_2d.reshape((1, p_s_hPa_2d.shape[0], p_s_hPa_2d.shape[1]))
    p_hi_3d_stacked = np.append(p_levels_3d, p_s_hPa_3d, axis=0)

    # Slice finite layers for high-pressure calculations
    q_finite_hi = q_hi_3d_stacked[17:, :, :]
    v_finite_hi = v_hi_3d_stacked[17:, :, :]
    p_finite_hi = p_hi_3d_stacked[17:, :, :]

    # Compute mid-layer averages
    q_mid_hi = (q_finite_hi[:-1, :, :] + q_finite_hi[1:, :, :]) / 2
    v_mid_hi = (v_finite_hi[:-1, :, :] + v_finite_hi[1:, :, :]) / 2
    dp_hi = np.abs(p_finite_hi[:-1, :, :] - p_finite_hi[1:, :, :])

    # Calculate vertically integrated vapor transport (high-pressure)
    vIVT_hi_2d = np.nansum(1 * (q_mid_hi * v_mid_hi * dp_hi) / g, axis=0)

    ## For Pressure less than or equal to 1000
    q_lo_3d = np.copy(q_3d)
    q2m_lo_2d = np.copy(q2m_2d)
    v_lo_3d = np.copy(v_3d)
    v10m_lo_2d = np.copy(v10_2d)

    q_lo_3d[:, p_s_hPa_2d > 1000] = 0.
    q2m_lo_2d[p_s_hPa_2d > 1000] = 0.
    v_lo_3d[:, p_s_hPa_2d > 1000] = 0.
    v10m_lo_2d[p_s_hPa_2d > 1000] = 0.

    # Stack the 2-m specific humidity onto the humidity profile array and v10 onto the v
    q2m_lo_3d = q2m_lo_2d.reshape((1, q2m_lo_2d.shape[0], q2m_lo_2d.shape[1]))
    q_lo_3d_stacked = np.append(q_lo_3d, q2m_lo_3d, axis=0)
    v10m_lo_3d = v10m_lo_2d.reshape((1, v10m_lo_2d.shape[0], v10m_lo_2d.shape[1]))
    v_lo_3d_stacked = np.append(v_lo_3d, v10m_lo_3d, axis=0)

    # Stack the surface pressure values onto the pressure levels array
    p_s_hPa_3d = p_s_hPa_2d.reshape((1, p_s_hPa_2d.shape[0], p_s_hPa_2d.shape[1]))
    p_lo_3d_stacked = np.append(p_levels_3d, p_s_hPa_3d, axis=0)
    from numba import jit
    @jit
    def compute_vIVT(q_lo_3d_stacked, v_lo_3d_stacked, p_lo_3d_stacked, p_s_hPa_2d):
        vIVT_lo_2d = np.zeros_like(vIVT_hi_2d)
        for i in range(721):
            for j in range(1440):
                p_new = p_lo_3d_stacked[17:, i, j][p_lo_3d_stacked[17:, i, j] <= p_s_hPa_2d[i, j]]
                q_new = q_lo_3d_stacked[17:, i, j][p_lo_3d_stacked[17:, i, j] <= p_s_hPa_2d[i, j]]
                v_new = v_lo_3d_stacked[17:, i, j][p_lo_3d_stacked[17:, i, j] <= p_s_hPa_2d[i, j]]

                # Trapezoidal integration
                q_mid_lo = (q_new[:-1] + q_new[1:]) / 2.
                v_mid_lo = (v_new[:-1] + v_new[1:]) / 2.
                dp_lo = np.abs(p_new[:-1] - p_new[1:])
                vIVT_lo_2d[i, j] = np.sum(1 * (q_mid_lo * v_mid_lo * dp_lo) / g, axis=0)

        return vIVT_lo_2d

    vIVT_lo_2d = compute_vIVT(q_lo_3d_stacked, v_lo_3d_stacked, p_lo_3d_stacked, p_s_hPa_2d)
    vIVT = (vIVT_hi_2d + vIVT_lo_2d) * 100
    vIVT_all_timesteps.append(vIVT)

vIVT_all_timesteps = np.array(vIVT_all_timesteps)
print("Processing complete. vIVT computed for all time steps.")
# Create a DataFrame for coordinates (latitude, longitude) and time
latitude = qdata.latitude.values  # Assuming latitude values are available in the qdata
longitude = qdata.longitude.values  # Assuming longitude values are available in the qdata
time = qdata.time.values  # Time steps from the dataset

# Create the dataset for vIVT
vivt_dataset = xr.Dataset(
    {
        'latitude': (['latitude'], latitude),
        'longitude': (['longitude'], longitude),
        'time': (['time'], time),
        'vivt': (['time', 'latitude', 'longitude'], vIVT_all_timesteps),
    }
)

# Specify the path to save the NetCDF file
vivt_nc_file = f"/g/data/k10/ak6086/vIVTsur/{year}/vivt{year}{month}.nc"

# Save to NetCDF
vivt_dataset.to_netcdf(vivt_nc_file, format='NETCDF4')

print("vIVT data saved successfully to NetCDF file.")
# Out:
# /home/565/ak6086/micromamba/envs/PhDAnalysis/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
# Processing time step 1/672
# Processing time step 2/672
# Processing time step 3/672
# Processing time step 4/672
# Processing time step 5/672
# Processing time step 6/672
# Processing time step 7/672
# Processing time step 8/672
# Processing time step 9/672
# Processing time step 10/672
# Processing time step 11/672
# Processing time step 12/672
# Processing time step 13/672
# Processing time step 14/672
# Processing time step 15/672
# Processing time step 16/672
# Processing time step 17/672
# Processing time step 18/672
# Processing time step 19/672
# Processing time step 20/672
# Processing time step 21/672
# Processing time step 22/672
# Processing time step 23/672
# Processing time step 24/672
# Processing time step 25/672
# Processing time step 26/672
# Processing time step 27/672
# Processing time step 28/672
# Processing time step 29/672
# Processing time step 30/672
# Processing time step 31/672
# Processing time step 32/672
# Processing time step 33/672
# Processing time step 34/672
# Processing time step 35/672
# Processing time step 36/672
# Processing time step 37/672
# Processing time step 38/672
# Processing time step 39/672
# Processing time step 40/672
# Processing time step 41/672
# Processing time step 42/672
# Processing time step 43/672
# Processing time step 44/672
# Processing time step 45/672
# Processing time step 46/672
# Processing time step 47/672
# Processing time step 48/672
# Processing time step 49/672
# Processing time step 50/672
# Processing time step 51/672
# Processing time step 52/672
# Processing time step 53/672
# Processing time step 54/672
# Processing time step 55/672
# Processing time step 56/672
# Processing time step 57/672
# Processing time step 58/672
# Processing time step 59/672
# Processing time step 60/672
# Processing time step 61/672
# Processing time step 62/672
# Processing time step 63/672
# Processing time step 64/672
# Processing time step 65/672
# Processing time step 66/672
# Processing time step 67/672
# Processing time step 68/672
# Processing time step 69/672
# Processing time step 70/672
# Processing time step 71/672
# Processing time step 72/672
# Processing time step 73/672
# Processing time step 74/672
# Processing time step 75/672
# Processing time step 76/672
# Processing time step 77/672
# Processing time step 78/672
# Processing time step 79/672
# Processing time step 80/672
# Processing time step 81/672
# Processing time step 82/672
# Processing time step 83/672
# Processing time step 84/672
# Processing time step 85/672
# Processing time step 86/672
# Processing time step 87/672
# Processing time step 88/672
# Processing time step 89/672
# Processing time step 90/672
# Processing time step 91/672
# Processing time step 92/672
# Processing time step 93/672
# Processing time step 94/672
# Processing time step 95/672
# Processing time step 96/672
# Processing time step 97/672
# Processing time step 98/672
# Processing time step 99/672
# Processing time step 100/672
# Processing time step 101/672
# Processing time step 102/672
# Processing time step 103/672
# Processing time step 104/672
# Processing time step 105/672
# Processing time step 106/672
# Processing time step 107/672
# Processing time step 108/672
# Processing time step 109/672
# Processing time step 110/672
# Processing time step 111/672
# Processing time step 112/672
# Processing time step 113/672
# Processing time step 114/672
# Processing time step 115/672
# Processing time step 116/672
# Processing time step 117/672
# Processing time step 118/672
# Processing time step 119/672
# Processing time step 120/672
# Processing time step 121/672
# Processing time step 122/672
# Processing time step 123/672
# Processing time step 124/672
# Processing time step 125/672
# Processing time step 126/672
# Processing time step 127/672
# Processing time step 128/672
# Processing time step 129/672
# Processing time step 130/672
# Processing time step 131/672
# Processing time step 132/672
# Processing time step 133/672
# Processing time step 134/672
# Processing time step 135/672
# Processing time step 136/672
# Processing time step 137/672
# Processing time step 138/672
# Processing time step 139/672
# Processing time step 140/672
# Processing time step 141/672
# Processing time step 142/672
# Processing time step 143/672
# Processing time step 144/672
# Processing time step 145/672
# Processing time step 146/672
# Processing time step 147/672
# Processing time step 148/672
# Processing time step 149/672
# Processing time step 150/672
# Processing time step 151/672
# Processing time step 152/672
# Processing time step 153/672
# Processing time step 154/672
# Processing time step 155/672
# Processing time step 156/672
# Processing time step 157/672
# Processing time step 158/672
# Processing time step 159/672
# Processing time step 160/672
# Processing time step 161/672
# Processing time step 162/672
# Processing time step 163/672
# Processing time step 164/672
# Processing time step 165/672
# Processing time step 166/672
# Processing time step 167/672
# Processing time step 168/672
# Processing time step 169/672
# Processing time step 170/672
# Processing time step 171/672
# Processing time step 172/672
# Processing time step 173/672
# Processing time step 174/672
# Processing time step 175/672
# Processing time step 176/672
# Processing time step 177/672
# Processing time step 178/672
# Processing time step 179/672
# Processing time step 180/672
# Processing time step 181/672
# Processing time step 182/672
# Processing time step 183/672
# Processing time step 184/672
# Processing time step 185/672
# Processing time step 186/672
# Processing time step 187/672
# Processing time step 188/672
# Processing time step 189/672
# Processing time step 190/672
# Processing time step 191/672
# Processing time step 192/672
# Processing time step 193/672
# Processing time step 194/672
# Processing time step 195/672
# Processing time step 196/672
# Processing time step 197/672
# Processing time step 198/672
# Processing time step 199/672
# Processing time step 200/672
# Processing time step 201/672
# Processing time step 202/672
# Processing time step 203/672
# Processing time step 204/672
# Processing time step 205/672
# Processing time step 206/672
# Processing time step 207/672
# Processing time step 208/672
# Processing time step 209/672
# Processing time step 210/672
# Processing time step 211/672
# Processing time step 212/672
# Processing time step 213/672
# Processing time step 214/672
# Processing time step 215/672
# Processing time step 216/672
# Processing time step 217/672
# Processing time step 218/672
# Processing time step 219/672
# Processing time step 220/672
# Processing time step 221/672
# Processing time step 222/672
# Processing time step 223/672
# Processing time step 224/672
# Processing time step 225/672
# Processing time step 226/672
# Processing time step 227/672
# Processing time step 228/672
# Processing time step 229/672
# Processing time step 230/672
# Processing time step 231/672
# Processing time step 232/672
# Processing time step 233/672
# Processing time step 234/672
# Processing time step 235/672
# Processing time step 236/672
# Processing time step 237/672
# Processing time step 238/672
# Processing time step 239/672
# Processing time step 240/672
# Processing time step 241/672
# Processing time step 242/672
# Processing time step 243/672
# Processing time step 244/672
# Processing time step 245/672
# Processing time step 246/672
# Processing time step 247/672
# Processing time step 248/672
# Processing time step 249/672
# Processing time step 250/672
# Processing time step 251/672
# Processing time step 252/672
# Processing time step 253/672
# Processing time step 254/672
# Processing time step 255/672
# Processing time step 256/672
# Processing time step 257/672
# Processing time step 258/672
# Processing time step 259/672
# Processing time step 260/672
# Processing time step 261/672
# Processing time step 262/672
# Processing time step 263/672
# Processing time step 264/672
# Processing time step 265/672
# Processing time step 266/672
# Processing time step 267/672
# Processing time step 268/672
# Processing time step 269/672
# Processing time step 270/672
# Processing time step 271/672
# Processing time step 272/672
# Processing time step 273/672
# Processing time step 274/672
# Processing time step 275/672
# Processing time step 276/672
# Processing time step 277/672
# Processing time step 278/672
# Processing time step 279/672
# Processing time step 280/672
# Processing time step 281/672
# Processing time step 282/672
# Processing time step 283/672
# Processing time step 284/672
# Processing time step 285/672
# Processing time step 286/672
# Processing time step 287/672
# Processing time step 288/672
# Processing time step 289/672
# Processing time step 290/672
# Processing time step 291/672
# Processing time step 292/672
# Processing time step 293/672
# Processing time step 294/672
# Processing time step 295/672
# Processing time step 296/672
# Processing time step 297/672
# Processing time step 298/672
# Processing time step 299/672
# Processing time step 300/672
# Processing time step 301/672
# Processing time step 302/672
# Processing time step 303/672
# Processing time step 304/672
# Processing time step 305/672
# Processing time step 306/672
# Processing time step 307/672
# Processing time step 308/672
# Processing time step 309/672
# Processing time step 310/672
# Processing time step 311/672
# Processing time step 312/672
# Processing time step 313/672
# Processing time step 314/672
# Processing time step 315/672
# Processing time step 316/672
# Processing time step 317/672
# Processing time step 318/672
# Processing time step 319/672
# Processing time step 320/672
# Processing time step 321/672
# Processing time step 322/672
# Processing time step 323/672
# Processing time step 324/672
# Processing time step 325/672
# Processing time step 326/672
# Processing time step 327/672
# Processing time step 328/672
# Processing time step 329/672
# Processing time step 330/672
# Processing time step 331/672
# Processing time step 332/672
# Processing time step 333/672
# Processing time step 334/672
# Processing time step 335/672
# Processing time step 336/672
# Processing time step 337/672
# Processing time step 338/672
# Processing time step 339/672
# Processing time step 340/672
# Processing time step 341/672
# Processing time step 342/672
# Processing time step 343/672
# Processing time step 344/672
# Processing time step 345/672
# Processing time step 346/672
# Processing time step 347/672
# Processing time step 348/672
# Processing time step 349/672
# Processing time step 350/672
# Processing time step 351/672
# Processing time step 352/672
# Processing time step 353/672
# Processing time step 354/672
# Processing time step 355/672
# Processing time step 356/672
# Processing time step 357/672
# Processing time step 358/672
# Processing time step 359/672
# Processing time step 360/672
# Processing time step 361/672
# Processing time step 362/672
# Processing time step 363/672
# Processing time step 364/672
# Processing time step 365/672
# Processing time step 366/672
# Processing time step 367/672
# Processing time step 368/672
# Processing time step 369/672
# Processing time step 370/672
# Processing time step 371/672
# Processing time step 372/672
# Processing time step 373/672
# Processing time step 374/672
# Processing time step 375/672
# Processing time step 376/672
# Processing time step 377/672
# Processing time step 378/672
# Processing time step 379/672
# Processing time step 380/672
# Processing time step 381/672
# Processing time step 382/672
# Processing time step 383/672
# Processing time step 384/672
# Processing time step 385/672
# Processing time step 386/672
# Processing time step 387/672
# Processing time step 388/672
# Processing time step 389/672
# Processing time step 390/672
# Processing time step 391/672
# Processing time step 392/672
# Processing time step 393/672
# Processing time step 394/672
# Processing time step 395/672
# Processing time step 396/672
# Processing time step 397/672
# Processing time step 398/672
# Processing time step 399/672
# Processing time step 400/672
# Processing time step 401/672
# Processing time step 402/672
# Processing time step 403/672
# Processing time step 404/672
# Processing time step 405/672
# Processing time step 406/672
# Processing time step 407/672
# Processing time step 408/672
# Processing time step 409/672
# Processing time step 410/672
# Processing time step 411/672
# Processing time step 412/672
# Processing time step 413/672
# Processing time step 414/672
# Processing time step 415/672
# Processing time step 416/672
# Processing time step 417/672
# Processing time step 418/672
# Processing time step 419/672
# Processing time step 420/672
# Processing time step 421/672
# Processing time step 422/672
# Processing time step 423/672
# Processing time step 424/672
# Processing time step 425/672
# Processing time step 426/672
# Processing time step 427/672
# Processing time step 428/672
# Processing time step 429/672
# Processing time step 430/672
# Processing time step 431/672
# Processing time step 432/672
# Processing time step 433/672
# Processing time step 434/672
# Processing time step 435/672
# Processing time step 436/672
# Processing time step 437/672
# Processing time step 438/672
# Processing time step 439/672
# Processing time step 440/672
# Processing time step 441/672
# Processing time step 442/672
# Processing time step 443/672
# Processing time step 444/672
# Processing time step 445/672
# Processing time step 446/672
# Processing time step 447/672
# Processing time step 448/672
# Processing time step 449/672
# Processing time step 450/672
# Processing time step 451/672
# Processing time step 452/672
# Processing time step 453/672
# Processing time step 454/672
# Processing time step 455/672
# Processing time step 456/672
# Processing time step 457/672
# Processing time step 458/672
# Processing time step 459/672
# Processing time step 460/672
# Processing time step 461/672
# Processing time step 462/672
# Processing time step 463/672
# Processing time step 464/672
# Processing time step 465/672
# Processing time step 466/672
# Processing time step 467/672
# Processing time step 468/672
# Processing time step 469/672
# Processing time step 470/672
# Processing time step 471/672
# Processing time step 472/672
# Processing time step 473/672
# Processing time step 474/672
# Processing time step 475/672
# Processing time step 476/672
# Processing time step 477/672
# Processing time step 478/672
# Processing time step 479/672
# Processing time step 480/672
# Processing time step 481/672
# Processing time step 482/672
# Processing time step 483/672
# Processing time step 484/672
# Processing time step 485/672
# Processing time step 486/672
# Processing time step 487/672
# Processing time step 488/672
# Processing time step 489/672
# Processing time step 490/672
# Processing time step 491/672
# Processing time step 492/672
# Processing time step 493/672
# Processing time step 494/672
# Processing time step 495/672
# Processing time step 496/672
# Processing time step 497/672
# Processing time step 498/672
# Processing time step 499/672
# Processing time step 500/672
# Processing time step 501/672
# Processing time step 502/672
# Processing time step 503/672
# Processing time step 504/672
# Processing time step 505/672
# Processing time step 506/672
# Processing time step 507/672
# Processing time step 508/672
# Processing time step 509/672
# Processing time step 510/672
# Processing time step 511/672
# Processing time step 512/672
# Processing time step 513/672
# Processing time step 514/672
# Processing time step 515/672
# Processing time step 516/672
# Processing time step 517/672
# Processing time step 518/672
# Processing time step 519/672
# Processing time step 520/672
# Processing time step 521/672
# Processing time step 522/672
# Processing time step 523/672
# Processing time step 524/672
# Processing time step 525/672
# Processing time step 526/672
# Processing time step 527/672
# Processing time step 528/672
# Processing time step 529/672
# Processing time step 530/672
# Processing time step 531/672
# Processing time step 532/672
# Processing time step 533/672
# Processing time step 534/672
# Processing time step 535/672
# Processing time step 536/672
# Processing time step 537/672
# Processing time step 538/672
# Processing time step 539/672
# Processing time step 540/672
# Processing time step 541/672
# Processing time step 542/672
# Processing time step 543/672
# Processing time step 544/672
# Processing time step 545/672
# Processing time step 546/672
# Processing time step 547/672
# Processing time step 548/672
# Processing time step 549/672
# Processing time step 550/672
# Processing time step 551/672
# Processing time step 552/672
# Processing time step 553/672
# Processing time step 554/672
# Processing time step 555/672
# Processing time step 556/672
# Processing time step 557/672
# Processing time step 558/672
# Processing time step 559/672
# Processing time step 560/672
# Processing time step 561/672
# Processing time step 562/672
# Processing time step 563/672
# Processing time step 564/672
# Processing time step 565/672
# Processing time step 566/672
# Processing time step 567/672
# Processing time step 568/672
# Processing time step 569/672
# Processing time step 570/672
# Processing time step 571/672
# Processing time step 572/672
# Processing time step 573/672
# Processing time step 574/672
# Processing time step 575/672
# Processing time step 576/672
# Processing time step 577/672
# Processing time step 578/672
# Processing time step 579/672
# Processing time step 580/672
# Processing time step 581/672
# Processing time step 582/672
# Processing time step 583/672
# Processing time step 584/672
# Processing time step 585/672
# Processing time step 586/672
# Processing time step 587/672
# Processing time step 588/672
# Processing time step 589/672
# Processing time step 590/672
# Processing time step 591/672
# Processing time step 592/672
# Processing time step 593/672
# Processing time step 594/672
# Processing time step 595/672
# Processing time step 596/672
# Processing time step 597/672
# Processing time step 598/672
# Processing time step 599/672
# Processing time step 600/672
# Processing time step 601/672
# Processing time step 602/672
# Processing time step 603/672
# Processing time step 604/672
# Processing time step 605/672
# Processing time step 606/672
# Processing time step 607/672
# Processing time step 608/672
# Processing time step 609/672
# Processing time step 610/672
# Processing time step 611/672
# Processing time step 612/672
# Processing time step 613/672
# Processing time step 614/672
# Processing time step 615/672
# Processing time step 616/672
# Processing time step 617/672
# Processing time step 618/672
# Processing time step 619/672
# Processing time step 620/672
# Processing time step 621/672
# Processing time step 622/672
# Processing time step 623/672
# Processing time step 624/672
# Processing time step 625/672
# Processing time step 626/672
# Processing time step 627/672
# Processing time step 628/672
# Processing time step 629/672
# Processing time step 630/672
# Processing time step 631/672
# Processing time step 632/672
# Processing time step 633/672
# Processing time step 634/672
# Processing time step 635/672
# Processing time step 636/672
# Processing time step 637/672
# Processing time step 638/672
# Processing time step 639/672
# Processing time step 640/672
# Processing time step 641/672
# Processing time step 642/672
# Processing time step 643/672
# Processing time step 644/672
# Processing time step 645/672
# Processing time step 646/672
# Processing time step 647/672
# Processing time step 648/672
# Processing time step 649/672
# Processing time step 650/672
# Processing time step 651/672
# Processing time step 652/672
# Processing time step 653/672
# Processing time step 654/672
# Processing time step 655/672
# Processing time step 656/672
# Processing time step 657/672
# Processing time step 658/672
# Processing time step 659/672
# Processing time step 660/672
# Processing time step 661/672
# Processing time step 662/672
# Processing time step 663/672
# Processing time step 664/672
# Processing time step 665/672
# Processing time step 666/672
# Processing time step 667/672
# Processing time step 668/672
# Processing time step 669/672
# Processing time step 670/672
# Processing time step 671/672
# Processing time step 672/672
# Processing complete. vIVT computed for all time steps.
# vIVT data saved successfully to NetCDF file.
