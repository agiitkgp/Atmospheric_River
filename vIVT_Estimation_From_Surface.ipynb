# %%
import os
import pandas as pd
import numpy as np
import xarray as xr
from datetime import datetime as dt
from scipy import integrate
import matplotlib.pyplot as plt
year = 1982  # Change this as needed
month = "03"  # Change this as needed (ensure two-digit format)
# Load data from NetCDF files
# Construct file paths dynamically
qdata = xr.open_dataset(f"q_folder/q/{year}/q_era5_oper_pl_{year}{month}01-{year}{month}31.nc") #q_Pressure_levels
q2mdata = xr.open_dataset(f"/q2m_folder/{year}/q2m_{year}{month}.nc") #q2m
vdata = xr.open_dataset(f"/v_folder/{year}/v_era5_oper_pl_{year}{month}01-{year}{month}31.nc") #Meridional velocity at pressure levels
v10mdata = xr.open_dataset(f"/10v_folder/{year}/10v_era5_oper_sfc_{year}{month}01-{year}{month}31.nc") #10m_Surface_Velocity
spdata = xr.open_dataset(f"/surface_Pressure_Folder/{year}/sp_era5_oper_sfc_{year}{month}01-{year}{month}31.nc") #Surface Pressure
time_steps = qdata.time
g=9.81
vIVT_all_timesteps = []
for tt in range(len(time_steps)):
    print(f"Processing time step {tt + 1}/{len(time_steps)}")

    # Extract surface pressure data
    p_s_xr_2d = spdata['sp'][tt, :, :]  # Surface pressure [Pa]
    p_s_2d = p_s_xr_2d.compute().values
    p_s_hPa_2d = p_s_2d / 1e2  # Convert pressure to hPa

    # Extract specific humidity at 2 meters and meridional velocity at 10 meters
    q2m_xr_2d = q2mdata['q2m'][tt, :, :]
    q2m_2d = q2m_xr_2d.compute().values
    v10_xr_2d = v10mdata['v10'][tt, :, :]
    v10_2d = v10_xr_2d.compute().values

    # Extract 3D specific humidity and meridional velocity
    xr_q_3d = qdata['q'][tt, :, :, :]  # Specific humidity [kg/kg]
    q_3d = xr_q_3d.compute().values
    xr_v_3d = vdata['v'][tt, :, :, :]  # Meridional velocity [m/s]
    v_3d = xr_v_3d.compute().values

    # Create copies for high-pressure calculations
    q_hi_3d = np.copy(q_3d)
    q2m_hi_2d = np.copy(q2m_2d)
    v_hi_3d = np.copy(v_3d)
    v10m_hi_2d = np.copy(v10_2d)

    # Set values to zero where surface pressure is less than 1000 hPa
    mask_low_pressure = p_s_hPa_2d < 1000
    q_hi_3d[:, mask_low_pressure] = 0.
    q2m_hi_2d[mask_low_pressure] = 0.
    v_hi_3d[:, mask_low_pressure] = 0.
    v10m_hi_2d[mask_low_pressure] = 0.

    # Reshape 2D fields to 3D for stacking
    q2m_hi_3d = q2m_hi_2d.reshape((1, q2m_hi_2d.shape[0], q2m_hi_2d.shape[1]))
    v10m_hi_3d = v10m_hi_2d.reshape((1, v10m_hi_2d.shape[0], v10m_hi_2d.shape[1]))

    # Stack high-pressure data
    q_hi_3d_stacked = np.append(q_hi_3d, q2m_hi_3d, axis=0)
    v_hi_3d_stacked = np.append(v_hi_3d, v10m_hi_3d, axis=0)

    # Define pressure levels
    p = qdata.level.values  # Pressure levels [hPa]
    p_levels_3d = np.zeros((len(p), q_3d.shape[1], q_3d.shape[2]))
    for i in range(len(p)):
        p_levels_3d[i, :, :] = p[i]

    # Add surface pressure as a new level
    p_s_hPa_3d = p_s_hPa_2d.reshape((1, p_s_hPa_2d.shape[0], p_s_hPa_2d.shape[1]))
    p_hi_3d_stacked = np.append(p_levels_3d, p_s_hPa_3d, axis=0)

    # Slice finite layers for high-pressure calculations
    q_finite_hi = q_hi_3d_stacked[17:, :, :]
    v_finite_hi = v_hi_3d_stacked[17:, :, :]
    p_finite_hi = p_hi_3d_stacked[17:, :, :]

    # Compute mid-layer averages
    q_mid_hi = (q_finite_hi[:-1, :, :] + q_finite_hi[1:, :, :]) / 2
    v_mid_hi = (v_finite_hi[:-1, :, :] + v_finite_hi[1:, :, :]) / 2
    dp_hi = np.abs(p_finite_hi[:-1, :, :] - p_finite_hi[1:, :, :])

    # Calculate vertically integrated vapor transport (high-pressure)
    vIVT_hi_2d = np.nansum(1 * (q_mid_hi * v_mid_hi * dp_hi) / g, axis=0)

    ## For Pressure less than or equal to 1000
    q_lo_3d = np.copy(q_3d)
    q2m_lo_2d = np.copy(q2m_2d)
    v_lo_3d = np.copy(v_3d)
    v10m_lo_2d = np.copy(v10_2d)

    q_lo_3d[:, p_s_hPa_2d > 1000] = 0.
    q2m_lo_2d[p_s_hPa_2d > 1000] = 0.
    v_lo_3d[:, p_s_hPa_2d > 1000] = 0.
    v10m_lo_2d[p_s_hPa_2d > 1000] = 0.

    # Stack the 2-m specific humidity onto the humidity profile array and v10 onto the v
    q2m_lo_3d = q2m_lo_2d.reshape((1, q2m_lo_2d.shape[0], q2m_lo_2d.shape[1]))
    q_lo_3d_stacked = np.append(q_lo_3d, q2m_lo_3d, axis=0)
    v10m_lo_3d = v10m_lo_2d.reshape((1, v10m_lo_2d.shape[0], v10m_lo_2d.shape[1]))
    v_lo_3d_stacked = np.append(v_lo_3d, v10m_lo_3d, axis=0)

    # Stack the surface pressure values onto the pressure levels array
    p_s_hPa_3d = p_s_hPa_2d.reshape((1, p_s_hPa_2d.shape[0], p_s_hPa_2d.shape[1]))
    p_lo_3d_stacked = np.append(p_levels_3d, p_s_hPa_3d, axis=0)
    from numba import jit
    @jit
    def compute_vIVT(q_lo_3d_stacked, v_lo_3d_stacked, p_lo_3d_stacked, p_s_hPa_2d):
        vIVT_lo_2d = np.zeros_like(vIVT_hi_2d)
        for i in range(721):
            for j in range(1440):
                p_new = p_lo_3d_stacked[17:, i, j][p_lo_3d_stacked[17:, i, j] <= p_s_hPa_2d[i, j]]
                q_new = q_lo_3d_stacked[17:, i, j][p_lo_3d_stacked[17:, i, j] <= p_s_hPa_2d[i, j]]
                v_new = v_lo_3d_stacked[17:, i, j][p_lo_3d_stacked[17:, i, j] <= p_s_hPa_2d[i, j]]

                # Trapezoidal integration
                q_mid_lo = (q_new[:-1] + q_new[1:]) / 2.
                v_mid_lo = (v_new[:-1] + v_new[1:]) / 2.
                dp_lo = np.abs(p_new[:-1] - p_new[1:])
                vIVT_lo_2d[i, j] = np.sum(1 * (q_mid_lo * v_mid_lo * dp_lo) / g, axis=0)

        return vIVT_lo_2d

    vIVT_lo_2d = compute_vIVT(q_lo_3d_stacked, v_lo_3d_stacked, p_lo_3d_stacked, p_s_hPa_2d)
    vIVT = (vIVT_hi_2d + vIVT_lo_2d) * 100
    vIVT_all_timesteps.append(vIVT)

vIVT_all_timesteps = np.array(vIVT_all_timesteps)
print("Processing complete. vIVT computed for all time steps.")
# Create a DataFrame for coordinates (latitude, longitude) and time
latitude = qdata.latitude.values  # Assuming latitude values are available in the qdata
longitude = qdata.longitude.values  # Assuming longitude values are available in the qdata
time = qdata.time.values  # Time steps from the dataset

# Create the dataset for vIVT
vivt_dataset = xr.Dataset(
    {
        'latitude': (['latitude'], latitude),
        'longitude': (['longitude'], longitude),
        'time': (['time'], time),
        'vivt': (['time', 'latitude', 'longitude'], vIVT_all_timesteps),
    }
)

# Specify the path to save the NetCDF file
vivt_nc_file = f"/Output_Directory/{year}/vivt{year}{month}.nc"

# Save to NetCDF
vivt_dataset.to_netcdf(vivt_nc_file, format='NETCDF4')

print("vIVT data saved successfully to NetCDF file.")
# Out:
# /home/565/ak6086/micromamba/envs/PhDAnalysis/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
# Processing time step 1/744
# Processing time step 2/744
# Processing time step 3/744
# Processing time step 4/744
# Processing time step 5/744
# Processing time step 6/744
# Processing time step 7/744
# Processing time step 8/744
# Processing time step 9/744
# Processing time step 10/744
# Processing time step 11/744
# Processing time step 12/744
# Processing time step 13/744
# Processing time step 14/744
# Processing time step 15/744
# Processing time step 16/744
# Processing time step 17/744
# Processing time step 18/744
# Processing time step 19/744
# Processing time step 20/744
# Processing time step 21/744
# Processing time step 22/744
# Processing time step 23/744
# Processing time step 24/744
# Processing time step 25/744
# Processing time step 26/744
# Processing time step 27/744
# Processing time step 28/744
# Processing time step 29/744
# Processing time step 30/744
# Processing time step 31/744
# Processing time step 32/744
# Processing time step 33/744
# Processing time step 34/744
# Processing time step 35/744
# Processing time step 36/744
# Processing time step 37/744
# Processing time step 38/744
# Processing time step 39/744
# Processing time step 40/744
# Processing time step 41/744
# Processing time step 42/744
# Processing time step 43/744
# Processing time step 44/744
# Processing time step 45/744
# Processing time step 46/744
# Processing time step 47/744
# Processing time step 48/744
# Processing time step 49/744
# Processing time step 50/744
# Processing time step 51/744
# Processing time step 52/744
# Processing time step 53/744
# Processing time step 54/744
# Processing time step 55/744
# Processing time step 56/744
# Processing time step 57/744
# Processing time step 58/744
# Processing time step 59/744
# Processing time step 60/744
# Processing time step 61/744
# Processing time step 62/744
# Processing time step 63/744
# Processing time step 64/744
# Processing time step 65/744
# Processing time step 66/744
# Processing time step 67/744
# Processing time step 68/744
# Processing time step 69/744
# Processing time step 70/744
# Processing time step 71/744
# Processing time step 72/744
# Processing time step 73/744
# Processing time step 74/744
# Processing time step 75/744
# Processing time step 76/744
# Processing time step 77/744
# Processing time step 78/744
# Processing time step 79/744
# Processing time step 80/744
# Processing time step 81/744
# Processing time step 82/744
# Processing time step 83/744
# Processing time step 84/744
# Processing time step 616/744
# Processing time step 617/744
# Processing time step 618/744
# Processing time step 619/744
# Processing time step 620/744
# Processing time step 621/744
# Processing time step 622/744
# Processing time step 623/744
# Processing time step 624/744
# Processing time step 625/744
# Processing time step 626/744
# Processing time step 627/744
# Processing time step 628/744
# Processing time step 629/744
# Processing time step 630/744
# Processing time step 631/744
# Processing time step 632/744
# Processing time step 633/744
# Processing time step 634/744
# Processing time step 635/744
# Processing time step 636/744
# Processing time step 637/744
# Processing time step 638/744
# Processing time step 639/744
# Processing time step 640/744
# Processing time step 641/744
# Processing time step 642/744
# Processing time step 643/744
# Processing time step 644/744
# Processing time step 645/744
# Processing time step 646/744
# Processing time step 647/744
# Processing time step 648/744
# Processing time step 649/744
# Processing time step 650/744
# Processing time step 651/744
# Processing time step 652/744
# Processing time step 653/744
# Processing time step 654/744
# Processing time step 655/744
# Processing time step 656/744
# Processing time step 657/744
# Processing time step 658/744
# Processing time step 659/744
# Processing time step 660/744
# Processing time step 661/744
# Processing time step 662/744
# Processing time step 663/744
# Processing time step 664/744
# Processing time step 665/744
# Processing time step 666/744
# Processing time step 667/744
# Processing time step 668/744
# Processing time step 669/744
# Processing time step 670/744
# Processing time step 671/744
# Processing time step 672/744
# Processing time step 673/744
# Processing time step 674/744
# Processing time step 675/744
# Processing time step 676/744
# Processing time step 677/744
# Processing time step 678/744
# Processing time step 679/744
# Processing time step 680/744
# Processing time step 681/744
# Processing time step 682/744
# Processing time step 683/744
# Processing time step 684/744
# Processing time step 685/744
# Processing time step 686/744
# Processing time step 687/744
# Processing time step 688/744
# Processing time step 689/744
# Processing time step 690/744
# Processing time step 691/744
# Processing time step 692/744
# Processing time step 693/744
# Processing time step 694/744
# Processing time step 695/744
# Processing time step 696/744
# Processing time step 697/744
# Processing time step 698/744
# Processing time step 699/744
# Processing time step 700/744
# Processing time step 701/744
# Processing time step 702/744
# Processing time step 703/744
# Processing time step 704/744
# Processing time step 705/744
# Processing time step 706/744
# Processing time step 707/744
# Processing time step 708/744
# Processing time step 709/744
# Processing time step 710/744
# Processing time step 711/744
# Processing time step 712/744
# Processing time step 713/744
# Processing time step 714/744
# Processing time step 715/744
# Processing time step 716/744
# Processing time step 717/744
# Processing time step 718/744
# Processing time step 719/744
# Processing time step 720/744
# Processing time step 721/744
# Processing time step 722/744
# Processing time step 723/744
# Processing time step 724/744
# Processing time step 725/744
# Processing time step 726/744
# Processing time step 727/744
# Processing time step 728/744
# Processing time step 729/744
# Processing time step 730/744
# Processing time step 731/744
# Processing time step 732/744
# Processing time step 733/744
# Processing time step 734/744
# Processing time step 735/744
# Processing time step 736/744
# Processing time step 737/744
# Processing time step 738/744
# Processing time step 739/744
# Processing time step 740/744
# Processing time step 741/744
# Processing time step 742/744
# Processing time step 743/744
# Processing time step 744/744
# Processing complete. vIVT computed for all time steps.
# vIVT data saved successfully to NetCDF file.
